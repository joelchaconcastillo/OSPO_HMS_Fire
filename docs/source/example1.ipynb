# %%
pip install HMSFire
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting HMSFire
#   Downloading HMSFire-0.3.13.tar.gz (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 KB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting basemap
#   Downloading basemap-1.3.6-cp39-cp39-manylinux1_x86_64.whl (864 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.1/864.1 KB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from HMSFire) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from HMSFire) (3.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from HMSFire) (2.27.1)
# Collecting datetime
#   Downloading DateTime-5.1-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from basemap->HMSFire) (1.22.4)
# Collecting matplotlib
#   Downloading matplotlib-3.6.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 46.4 MB/s eta 0:00:00
# Collecting pyshp<2.4,>=1.2
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 KB 5.6 MB/s eta 0:00:00
# Collecting pyproj<3.5.0,>=1.9.3
#   Downloading pyproj-3.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 67.7 MB/s eta 0:00:00
# Collecting basemap-data<1.4,>=1.3.2
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 46.0 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->HMSFire) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->HMSFire) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->HMSFire) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->HMSFire) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->HMSFire) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->HMSFire) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->HMSFire) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->HMSFire) (3.0.9)
# Collecting zope.interface
#   Downloading zope.interface-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 KB 27.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from datetime->HMSFire) (2022.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->HMSFire) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->HMSFire) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->HMSFire) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->HMSFire) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->HMSFire) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from zope.interface->datetime->HMSFire) (67.6.1)
# Building wheels for collected packages: HMSFire
#   Building wheel for HMSFire (setup.py) ... done
#   Created wheel for HMSFire: filename=HMSFire-0.3.13-py3-none-any.whl size=124805 sha256=d5b35f02c503364f39bb0afd1c7cf1ca3b58e72c7a6394cb83414cf12fe75e1c
#   Stored in directory: /root/.cache/pip/wheels/36/36/1a/ab17eaa32ca2418f3b53aa713cb049d1b1b9bb776257ba0104
# Successfully built HMSFire
# Installing collected packages: zope.interface, pyshp, pyproj, basemap-data, matplotlib, datetime, basemap, HMSFire
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed HMSFire-0.3.13 basemap-1.3.6 basemap-data-1.3.2 datetime-5.1 matplotlib-3.6.3 pyproj-3.4.1 pyshp-2.3.1 zope.interface-6.0

# %%
from OSPO.HMSFire import HMSF
Fires = HMSF.HMSFire(startDate='2023-01-01', endDate='2023-02-01')
data = Fires.getDataFrame()
Fires.plot()
print(Fires.satelites())
Fires.plot(minlon=-125, minlat=25, maxlon=-60, maxlat=50)
print(data)
# Out:
# Downloading.... 0.00 %
# Downloading.... 3.23 %
# Downloading.... 6.45 %
# Downloading.... 9.68 %
# Downloading.... 12.90 %
# Downloading.... 16.13 %
# Downloading.... 19.35 %
# Downloading.... 22.58 %
# Downloading.... 25.81 %
# Downloading.... 29.03 %
# Downloading.... 32.26 %
# Downloading.... 35.48 %
# Downloading.... 38.71 %
# Downloading.... 41.94 %
# Downloading.... 45.16 %
# Downloading.... 48.39 %
# Downloading.... 51.61 %
# Downloading.... 54.84 %
# Downloading.... 58.06 %
# Downloading.... 61.29 %
# Downloading.... 64.52 %
# Downloading.... 67.74 %
# Downloading.... 70.97 %
# Downloading.... 74.19 %
# Downloading.... 77.42 %
# Downloading.... 80.65 %
# Downloading.... 83.87 %
# Downloading.... 87.10 %
# Downloading.... 90.32 %
# Downloading.... 93.55 %
# Downloading.... 96.77 %
# Downloading.... 100.00 %
# warning: width and height keywords ignored for Cylindrical Equidistant projection
# ['NOAA 20' 'GOES-EAST' 'SUOMI NPP' 'GOES-WEST']
# warning: width and height keywords ignored for Cylindrical Equidistant projection
#               Lon        Lat  YearDay       Time  Satellite Method  Ecosystem  \
# 0      -78.024200  21.362741  2023001 2023-01-01    NOAA 20  VIIRS         24
# 1      -78.016762  21.362217  2023001 2023-01-01    NOAA 20  VIIRS         24
# 2      -78.031593  21.363262  2023001 2023-01-01    NOAA 20  VIIRS         24
# 3      -78.032242  21.356182  2023001 2023-01-01    NOAA 20  VIIRS         24
# 4      -78.024864  21.355663  2023001 2023-01-01    NOAA 20  VIIRS         24
# ...           ...        ...      ...        ...        ...    ...        ...
# 10206  -92.194366  16.078138  2023033 2023-02-01  GOES-EAST    FDC         93
# 10207 -103.338005  19.621122  2023033 2023-02-01  GOES-EAST    FDC         47
# 10208  -92.194366  16.078144  2023033 2023-02-01  GOES-EAST    FDC         93
# 10209  -79.147385  21.855923  2023033 2023-02-01  GOES-EAST    FDC         93
# 10210  -75.983391  20.552130  2023033 2023-02-01  GOES-EAST    FDC         93
#
#           FRP
# 0       4.371
# 1      13.332
# 2       4.371
# 3       4.371
# 4       4.371
# ...       ...
# 10206  57.944
# 10207  41.076
# 10208  65.903
# 10209  20.622
# 10210  23.827
#
# [215685 rows x 8 columns]
